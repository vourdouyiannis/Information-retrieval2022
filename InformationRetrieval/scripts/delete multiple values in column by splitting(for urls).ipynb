# %%
import pandas as pd

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-19-628ea4fd210b> in <module>
# ----> 1 import spark.sqlContext.implicits._
#
# ModuleNotFoundError: No module named 'spark'

# %%
df = pd.read_csv('C://LUCENE PROJECT//myfiles_2000.csv', delimiter=',', encoding='utf-8')

# %%
# Out:
#                                                     0  \
# 0              https://doi.org/10.3201/eid2708.210502
# 1   http://medrxiv.org/cgi/content/short/2021.07.2...
# 2   https://api.elsevier.com/content/article/pii/S...
# 3   https://www.ncbi.nlm.nih.gov/pmc/articles/PMC8...
# 4   http://medrxiv.org/cgi/content/short/2021.07.2...
# 5   https://api.elsevier.com/content/article/pii/S...
# 6                  https://doi.org/10.1111/nicc.12688
# 7            https://doi.org/10.1182/blood.2021011958
# 8          https://doi.org/10.1038/s41467-021-24940-w
# 9                https://doi.org/10.1128/cmr.00109-21
# 10      https://www.ncbi.nlm.nih.gov/pubmed/34322810/
#
#                                                     1
# 0       https://www.ncbi.nlm.nih.gov/pubmed/34287124/
# 1                                                None
# 2    https://www.sciencedirect.com/science/article...
# 3                                                None
# ...

# %%
df
# Out:
#                                                   title  \
# 0     SARS-CoV-2 Prevalence among Outpatients during...
# 1     Gender differences in housework and childcare ...
# 2     Longitudinal analysis of SARS-CoV-2 seropreval...
# 3      Der geriatrische Patient auf der Intensivstation
# 4     Wastewater surveillance for infectious disease...
# ...                                                 ...
# 2330  Trial watch : the gut microbiota as a tool to ...
# 2331  The effect of exposure to long working hours o...
# 2332  Increasing melanoma awareness amongst health a...
# 2333  Pooling of nasopharyngeal swab specimens for S...
# 2334  Antimicrobial use, drug-resistant infections a...
#
#                                                abstract publish_time  \
# 0     During the July 2020 first wave of severe acut...   2021-08-01
# 1     Objectives: Although gender stereotypes regard...   2021-07-31
# 2     Current SARS-CoV-2 serological tests are based...   2021-07-31
# ...

# %%
df[['url','url2']] = df['url'].str.split(';', 1, expand = True)
#because the file contents multiple values in the same cell in column url we have to create a new column and the extra urls in that column

# %%
df
# Out:
#                                                   title  \
# 0     SARS-CoV-2 Prevalence among Outpatients during...
# 1     Gender differences in housework and childcare ...
# 2     Longitudinal analysis of SARS-CoV-2 seropreval...
# 3      Der geriatrische Patient auf der Intensivstation
# 4     Wastewater surveillance for infectious disease...
# ...                                                 ...
# 2330  Trial watch : the gut microbiota as a tool to ...
# 2331  The effect of exposure to long working hours o...
# 2332  Increasing melanoma awareness amongst health a...
# 2333  Pooling of nasopharyngeal swab specimens for S...
# 2334  Antimicrobial use, drug-resistant infections a...
#
#                                                abstract publish_time  \
# 0     During the July 2020 first wave of severe acut...   2021-08-01
# 1     Objectives: Although gender stereotypes regard...   2021-07-31
# 2     Current SARS-CoV-2 serological tests are based...   2021-07-31
# ...

# %%
df.drop('url2', axis=1, inplace=True)
#drops the extra column

# %%
df
# Out:
#                                                   title  \
# 0     SARS-CoV-2 Prevalence among Outpatients during...
# 1     Gender differences in housework and childcare ...
# 2     Longitudinal analysis of SARS-CoV-2 seropreval...
# 3      Der geriatrische Patient auf der Intensivstation
# 4     Wastewater surveillance for infectious disease...
# ...                                                 ...
# 2330  Trial watch : the gut microbiota as a tool to ...
# 2331  The effect of exposure to long working hours o...
# 2332  Increasing melanoma awareness amongst health a...
# 2333  Pooling of nasopharyngeal swab specimens for S...
# 2334  Antimicrobial use, drug-resistant infections a...
#
#                                                abstract publish_time  \
# 0     During the July 2020 first wave of severe acut...   2021-08-01
# 1     Objectives: Although gender stereotypes regard...   2021-07-31
# 2     Current SARS-CoV-2 serological tests are based...   2021-07-31
# ...

# %%
#df.rename(columns={'url1': 'url'}, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   title          11 non-null     object
#  1   abstract_text  11 non-null     object
#  2   publish_time   11 non-null     object
#  3   authors        11 non-null     object
#  4   url            11 non-null     object
# dtypes: object(5)
# memory usage: 568.0+ bytes

# %%
df.to_csv('C://LUCENE PROJECT//mytestsample55.csv', index=False, encoding='utf-8')

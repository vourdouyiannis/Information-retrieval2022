# %%
import pandas as pd

# %%
df = pd.read_csv('C://LUCENE PROJECT//NEWKAGGLEmetadata-6-mono-sthles.csv', delimiter=',', encoding='utf-8')

# %%
print (df.head())
#show the header
# Out:
#                                                title  \
# 0  Clinical features of culture-proven Mycoplasma...
# 1  Nitric oxide: a pro-inflammatory mediator in l...
# 2    Surfactant protein-D and pulmonary host defense
# 3               Role of endothelin-1 in lung disease
# 4  Gene expression in epithelial cells in respons...
#
#                                             abstract publish_time  \
# 0  OBJECTIVE: This retrospective chart review des...   2001-07-04
# 1  Inflammatory diseases of the respiratory tract...   2000-08-15
# 2  Surfactant protein-D (SP-D) participates in th...   2000-08-25
# 3  Endothelin-1 (ET-1) is a 21 amino acid peptide...   2001-02-22
# 4  Respiratory syncytial virus (RSV) and pneumoni...   2001-05-11
#
#                                              authors  \
# 0                Madani, Tariq A; Al-Ghamdi, Aisha A
# 1  Vliet, Albert van der; Eiserich, Jason P; Cros...
# 2                                    Crouch, Erika C
# ...

# %%
df.sort_values(by=['publish_time'], inplace=True, ascending=False)
#sort based on the header publish_time from the oldest to the newest

# %%
print (df.head())
# Out:
#                                                     title  \
# 55204   COVID-19 Vaccine Priority for People With Neur...
# 675297  Chapter 6 Allocating scarce medical resources:...
# 544418    Chapter 11 COVID-19: Lessons from the frontline
# 650055  Chapter 3 My experience with the novel coronav...
# 656785                Chapter 15 Millennials and COVID-19
#
#                                                  abstract publish_time  \
# 55204                                                 NaN   2024-04-20
# 675297  Life changed from 1min to the next. It is one ...   2022-12-31
# 544418  The global spread of coronavirus disease 2019 ...   2022-12-31
# 650055  “She’s young,” I thought to myself one night a...   2022-12-31
# 656785  News about this novel virus that was striking ...   2022-12-31
#
#                                                   authors  \
# 55204     Pfeffer, Gerald; Jacob, Sarah; Preston, Jeffrey
# 675297               Díaz, Marilia; Steuer, Jacqueline Y.
# ...

# %%
df.loc[df['publish_time'] >= '2020-01-01']
#take all the elements from 2020-01-01 and above
# Out:
#                                                     title  \
# 55204   COVID-19 Vaccine Priority for People With Neur...
# 675297  Chapter 6 Allocating scarce medical resources:...
# 544418    Chapter 11 COVID-19: Lessons from the frontline
# 650055  Chapter 3 My experience with the novel coronav...
# 656785                Chapter 15 Millennials and COVID-19
# ...                                                   ...
# 89301   Absence of asymptomatic unruptured renal arter...
# 101108  Pathogenicity of a QX-like avian infectious br...
# 105846  Wound complication among different skin closur...
# 170450  Global Collaboration in Times of COVID-19: Cub...
# 11242   The Mycobiome in Health and Disease: Emerging ...
#
#                                                  abstract publish_time  \
# 55204                                                 NaN   2024-04-20
# 675297  Life changed from 1min to the next. It is one ...   2022-12-31
# ...

# %%
df.loc[~(df['publish_time'] <= '2020-01-01')]
# Out:
#                                                     title  \
# 55204   COVID-19 Vaccine Priority for People With Neur...
# 675297  Chapter 6 Allocating scarce medical resources:...
# 544418    Chapter 11 COVID-19: Lessons from the frontline
# 650055  Chapter 3 My experience with the novel coronav...
# 656785                Chapter 15 Millennials and COVID-19
# ...                                                   ...
# 516194  Hydroxychloroquine Treatment may Benefit Nucle...
# 516723  Spherical Fuzzy Cost/Benefit Analysis of Wind ...
# 519597  A hybrid deep transfer learning modelResults with mac...
# 527285  Institutional Measures to Support Industrial E...
# 529979  Municipal solid wastes: guidelines for design,...
#
#                                                  abstract publish_time  \
# 55204                                                 NaN   2024-04-20
# 675297  Life changed from 1min to the next. It is one ...   2022-12-31
# ...

# %%
df.loc[df['publish_time'] <= '2021-08-15']
#sort from 2021-08-15 and below
# Out:
#                                                     title  \
# 543350  Biocide-tolerance and antibiotic-resistance in...
# 546046  Post COVID-19 pandemic: Biofragmentation and s...
# 603792  An electrochemical biosensor for sensitive ana...
# 89594   Rapid in-situ analysis of phthalates in face m...
# 144340  ASTRO survey details effects of COVID-19 on ra...
# ...                                                   ...
# 179430                                         Editorial.
# 172114                                         Editorial.
# 172855                                         Editorial.
# 174841                                         Editorial.
# 176164                                      On Contagion.
#
#                                                  abstract publish_time  \
# 543350  During the current pandemic, chemical disinfec...   2021-08-15
# 546046  Because of the COVID-19 pandemic, used face ma...   2021-08-15
# ...

# %%
df.reset_index(drop=True, inplace=True)
#resets indesx

# %%
df
#shows files
# Out:
#                                                     title  \
# 0       COVID-19 Vaccine Priority for People With Neur...
# 1       Chapter 6 Allocating scarce medical resources:...
# 2         Chapter 11 COVID-19: Lessons from the frontline
# 3       Chapter 3 My experience with the novel coronav...
# 4                     Chapter 15 Millennials and COVID-19
# ...                                                   ...
# 729749  Hydroxychloroquine Treatment may Benefit Nucle...
# 729750  Spherical Fuzzy Cost/Benefit Analysis of Wind ...
# 729751  A hybrid deep transfer learning modelResults with mac...
# 729752  Institutional Measures to Support Industrial E...
# 729753  Municipal solid wastes: guidelines for design,...
#
#                                                  abstract publish_time  \
# 0                                                     NaN   2024-04-20
# 1       Life changed from 1min to the next. It is one ...   2022-12-31
# ...

# %%
df.loc[df['publish_time'] <= '2021-08-15']
# Out:
#                                                     title  \
# 403     Biocide-tolerance and antibiotic-resistance in...
# 404     Post COVID-19 pandemic: Biofragmentation and s...
# 405     An electrochemical biosensor for sensitive ana...
# 406     Rapid in-situ analysis of phthalates in face m...
# 407     ASTRO survey details effects of COVID-19 on ra...
# ...                                                   ...
# 729523                                         Editorial.
# 729524                                         Editorial.
# 729525                                         Editorial.
# 729526                                         Editorial.
# 729527                                      On Contagion.
#
#                                                  abstract publish_time  \
# 403     During the current pandemic, chemical disinfec...   2021-08-15
# 404     Because of the COVID-19 pandemic, used face ma...   2021-08-15
# ...

# %%
df.drop(df.index[:403], axis=0, inplace=True)
#takes elements beginning from 403 and above
#df.drop(df.index[[0,2]])
#df.drop(df.index[:3], inplace=True)

# %%
df.reset_index(drop=True, inplace=True)
#reset index and now the then 403 row becomes the 1 row

# %%
df
# Out:
#                                                     title  \
# 0       Biocide-tolerance and antibiotic-resistance in...
# 1       Post COVID-19 pandemic: Biofragmentation and s...
# 2       An electrochemical biosensor for sensitive ana...
# 3       Rapid in-situ analysis of phthalates in face m...
# 4       ASTRO survey details effects of COVID-19 on ra...
# ...                                                   ...
# 399995  The COVID‐19 information pandemic: how have we...
# 399996  The new frontier of consumer experiences: esca...
# 399997  A novel plan to deal with SARS‐CoV‐2 and COVID...
# 399998  Endoprotector: Protective box for safe endosco...
# 399999  Changes in the Clinical Practice of Ophthalmol...
#
#                                                  abstract publish_time  \
# 0       During the current pandemic, chemical disinfec...   2021-08-15
# 1       Because of the COVID-19 pandemic, used face ma...   2021-08-15
# ...

# %%
print (df.head())
# Out:
#                                                title  \
# 0  Biocide-tolerance and antibiotic-resistance in...
# 1  Post COVID-19 pandemic: Biofragmentation and s...
# 2  An electrochemical biosensor for sensitive ana...
# 3  Rapid in-situ analysis of phthalates in face m...
# 4  ASTRO survey details effects of COVID-19 on ra...
#
#                                             abstract publish_time  \
# 0  During the current pandemic, chemical disinfec...   2021-08-15
# 1  Because of the COVID-19 pandemic, used face ma...   2021-08-15
# 2  The pandemic of coronavirus disease 2019 (COVI...   2021-08-15
# 3  Phthalates (PAEs) are known as endocrine disru...   2021-08-15
# 4                                                NaN   2021-08-15
#
#                                              authors  \
# 0            Chen, Bo; Han, Jie; Dai, Han; Jia, Puqi
# 1                         Kwak, Jin Il; An, Youn-Joo
# 2  Peng, Ying; Pan, Yanhong; Sun, Zhaowei; Li, Ji...
# ...

# %%
df.drop(df.index[400000:], axis=0, inplace=True)
#delete everything but 399999 files

# %%
df
# Out:
#                                                     title  \
# 0       Biocide-tolerance and antibiotic-resistance in...
# 1       Post COVID-19 pandemic: Biofragmentation and s...
# 2       An electrochemical biosensor for sensitive ana...
# 3       Rapid in-situ analysis of phthalates in face m...
# 4       ASTRO survey details effects of COVID-19 on ra...
# ...                                                   ...
# 399995  The COVID‐19 information pandemic: how have we...
# 399996  The new frontier of consumer experiences: esca...
# 399997  A novel plan to deal with SARS‐CoV‐2 and COVID...
# 399998  Endoprotector: Protective box for safe endosco...
# 399999  Changes in the Clinical Practice of Ophthalmol...
#
#                                                  abstract publish_time  \
# 0       During the current pandemic, chemical disinfec...   2021-08-15
# 1       Because of the COVID-19 pandemic, used face ma...   2021-08-15
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 400000 entries, 0 to 399999
# Data columns (total 5 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   title         399760 non-null  object
#  1   abstract      304839 non-null  object
#  2   publish_time  400000 non-null  object
#  3   authors       393440 non-null  object
#  4   url           244572 non-null  object
# dtypes: object(5)
# memory usage: 18.3+ MB

# %%
#df['publish_time'] = pd.to_datetime(df['publish_time'])

# %%
#res = df[~(df['publish_time'] < '2014-03-18')]

# %%
#df.to_csv('C://LUCENE PROJECT//NEWKAGGLEmetadata1.csv', encoding='utf-8')

# %%
#df['publish_time'] = pd.to_datetime(df['publish_time'])

# %%
#res = df[~(df['publish_time'] < '2018-02-09')]

# %%
df.to_csv('C://LUCENE PROJECT//NEWKAGGLEmetadata-stoixismeno-400000.csv', index=False, encoding='utf-8')
#saves to csv

# %%
print (df.head())
# Out:
#                                                title  \
# 0  Biocide-tolerance and antibiotic-resistance in...
# 1  Post COVID-19 pandemic: Biofragmentation and s...
# 2  An electrochemical biosensor for sensitive ana...
# 3  Rapid in-situ analysis of phthalates in face m...
# 4  ASTRO survey details effects of COVID-19 on ra...
#
#                                             abstract publish_time  \
# 0  During the current pandemic, chemical disinfec...   2021-08-15
# 1  Because of the COVID-19 pandemic, used face ma...   2021-08-15
# 2  The pandemic of coronavirus disease 2019 (COVI...   2021-08-15
# 3  Phthalates (PAEs) are known as endocrine disru...   2021-08-15
# 4                                                NaN   2021-08-15
#
#                                              authors  \
# 0            Chen, Bo; Han, Jie; Dai, Han; Jia, Puqi
# 1                         Kwak, Jin Il; An, Youn-Joo
# 2  Peng, Ying; Pan, Yanhong; Sun, Zhaowei; Li, Ji...
# ...

# %%
df
# Out:
#                                                     title  \
# 0       Biocide-tolerance and antibiotic-resistance in...
# 1       Post COVID-19 pandemic: Biofragmentation and s...
# 2       An electrochemical biosensor for sensitive ana...
# 3       Rapid in-situ analysis of phthalates in face m...
# 4       ASTRO survey details effects of COVID-19 on ra...
# ...                                                   ...
# 399995  The COVID‐19 information pandemic: how have we...
# 399996  The new frontier of consumer experiences: esca...
# 399997  A novel plan to deal with SARS‐CoV‐2 and COVID...
# 399998  Endoprotector: Protective box for safe endosco...
# 399999  Changes in the Clinical Practice of Ophthalmol...
#
#                                                  abstract publish_time  \
# 0       During the current pandemic, chemical disinfec...   2021-08-15
# 1       Because of the COVID-19 pandemic, used face ma...   2021-08-15
# ...

# %%
df.loc[~(df['publish_time'] <= '2020-01-01')]
# Out:
#         Unnamed: 0                                              title  \
# 55204        55204  COVID-19 Vaccine Priority for People With Neur...
# 675297      675297  Chapter 6 Allocating scarce medical resources:...
# 544418      544418    Chapter 11 COVID-19: Lessons from the frontline
# 650055      650055  Chapter 3 My experience with the novel coronav...
# 656785      656785                Chapter 15 Millennials and COVID-19
# ...            ...                                                ...
# 516194      516194  Hydroxychloroquine Treatment may Benefit Nucle...
# 516723      516723  Spherical Fuzzy Cost/Benefit Analysis of Wind ...
# 519597      519597  A hybrid deep transfer learning modelResults with mac...
# 527285      527285  Institutional Measures to Support Industrial E...
# 529979      529979  Municipal solid wastes: guidelines for design,...
#
#                                                  abstract publish_time  \
# ...

# %%
df.to_csv('C://LUCENE PROJECT//NEWKAGGLEmetadata-kommeno2.csv', delimiter=',', index= False, encoding='utf-8')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 729754 entries, 55204 to 529979
# Data columns (total 6 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Unnamed: 0    729754 non-null  int64
#  1   title         729409 non-null  object
#  2   abstract      538122 non-null  object
#  3   publish_time  729528 non-null  object
#  4   authors       712840 non-null  object
#  5   url           385447 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 39.0+ MB

# %%
df.columns.str.match('Unnamed')
df.loc[:,~df.columns.str.match('Unnamed')]
#finds columns that include some invalid element and drops the coresponding row
# Out:
#                                                     title  \
# 55204   COVID-19 Vaccine Priority for People With Neur...
# 675297  Chapter 6 Allocating scarce medical resources:...
# 544418    Chapter 11 COVID-19: Lessons from the frontline
# 650055  Chapter 3 My experience with the novel coronav...
# 656785                Chapter 15 Millennials and COVID-19
# ...                                                   ...
# 516194  Hydroxychloroquine Treatment may Benefit Nucle...
# 516723  Spherical Fuzzy Cost/Benefit Analysis of Wind ...
# 519597  A hybrid deep transfer learning modelResults with mac...
# 527285  Institutional Measures to Support Industrial E...
# 529979  Municipal solid wastes: guidelines for design,...
#
#                                                  abstract publish_time  \
# 55204                                                 NaN   2024-04-20
# 675297  Life changed from 1min to the next. It is one ...   2022-12-31
# ...

# %%
df.to_csv('C://LUCENE PROJECT//NEWKAGGLEmetadata-kommeno3.csv', delimiter=',', index=False, encoding='utf-8')

# %%
df
# Out:
#         Unnamed: 0                                              title  \
# 0           543350  Biocide-tolerance and antibiotic-resistance in...
# 1           546046  Post COVID-19 pandemic: Biofragmentation and s...
# 2           603792  An electrochemical biosensor for sensitive ana...
# 3            89594  Rapid in-situ analysis of phthalates in face m...
# 4           144340  ASTRO survey details effects of COVID-19 on ra...
# ...            ...                                                ...
# 399995      710501  The COVID‐19 information pandemic: how have we...
# 399996       31745  The new frontier of consumer experiences: esca...
# 399997      651803  A novel plan to deal with SARS‐CoV‐2 and COVID...
# 399998      546914  Endoprotector: Protective box for safe endosco...
# 399999      619273  Changes in the Clinical Practice of Ophthalmol...
#
#                                                  abstract publish_time  \
# ...

# %%
df.drop(df.index[100001:], axis=0, inplace=True)
#drops everything but the first 100000 files

# %%
df
# Out:
#                                                     title  \
# 0       Biocide-tolerance and antibiotic-resistance in...
# 1       Post COVID-19 pandemic: Biofragmentation and s...
# 2       An electrochemical biosensor for sensitive ana...
# 3       Rapid in-situ analysis of phthalates in face m...
# 4       ASTRO survey details effects of COVID-19 on ra...
# ...                                                   ...
# 99996   Bronchoalveolar lavage affects thorax computed...
# 99997   Intraocular Pressure Telemetry for Managing Gl...
# 99998   Clinical and laboratory follow-up after hospit...
# 99999   Bipartisan politics and poverty as a risk fact...
# 100000  Potential Effects of COVID-19 on Cytochrome P4...
#
#                                                  abstract publish_time  \
# 0       During the current pandemic, chemical disinfec...   2021-08-15
# 1       Because of the COVID-19 pandemic, used face ma...   2021-08-15
# ...

# %%
#df.drop(df.index[0:5000], axis=0, inplace=True) ---->edw
#ok this one if you want to further cut down the files
#df.drop(df.index[100001:], axis=0, inplace=True)

# %%
df.drop(df.index[50001:], axis=0, inplace=True)
#ok this one if you want to further cut down the files

# %%
df.to_csv('C://LUCENE PROJECT//NEWKAGGLEmetadata-kommeno4.csv', delimiter=',', index=False, encoding='utf-8')
